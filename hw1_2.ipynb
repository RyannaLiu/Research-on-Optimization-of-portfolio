# %%
import numpy as np
import pandas as pd
import scipy.stats as scs

# %%
data=pd.read_excel('hw1.xlsx')

# %%
data=pd.DataFrame(data)

# %%
data.set_index(['Date'],inplace=True)

# %%
data.index
# Out:
# DatetimeIndex(['1999-01-04', '1999-01-05', '1999-01-06', '1999-01-07',
#                '1999-01-08', '1999-01-11', '1999-01-12', '1999-01-13',
#                '1999-01-14', '1999-01-15',
#                ...
#                '2016-11-25', '2016-11-28', '2016-11-29', '2016-11-30',
#                '2016-12-01', '2016-12-02', '2016-12-05', '2016-12-06',
#                '2016-12-07', '2016-12-08'],
#               dtype='datetime64[ns]', name='Date', length=4517, freq=None)

# %%
data_pct=data.pct_change()

# %%
data_pct=data_pct.iloc[1:,:]
data_pct
# Out:
#             SPTR Index  FNERTR Index  RU10INTR Index  SPGSCITR Index  \
# Date
# 1999-01-05    0.013624      0.003760        0.012301       -0.008623
# 1999-01-06    0.022368      0.001503        0.021337        0.029791
# 1999-01-07   -0.001991     -0.006748       -0.000946        0.002096
# 1999-01-08    0.004222      0.000300        0.004282        0.003761
# 1999-01-11   -0.008791     -0.003153       -0.007108        0.010479
# ...                ...           ...             ...             ...
# 2016-12-02    0.000397      0.010506        0.000402        0.004221
# 2016-12-05    0.005918      0.007937        0.006376        0.009845
# 2016-12-06    0.003439      0.004543        0.004042       -0.007819
# 2016-12-07    0.013359      0.020651        0.013009       -0.011434
# 2016-12-08    0.002259      0.005557        0.002801        0.007634
#
#             GDDUEAFE Index  LBUSTRUU Index  LF98TRUU Index  GDLEEGF Index
# Date
# ...

# %%
pct_mean=pd.DataFrame(data_pct.mean(),columns=['mean']).T
pct_std=pd.DataFrame(data_pct.std(),columns=['std']).T
pct_skew=pd.DataFrame(data_pct.skew(),columns=['skew']).T

# %%
sta=pd.concat([pct_mean,pct_std,pct_skew])
sta
# Out:
#       SPTR Index  FNERTR Index  RU10INTR Index  SPGSCITR Index  \
# mean    0.000286      0.000572        0.000298        0.000148
# std     0.012398      0.018276        0.012473        0.014844
# skew    0.001377      0.415645       -0.020924       -0.140288
#
#       GDDUEAFE Index  LBUSTRUU Index  LF98TRUU Index  GDLEEGF Index
# mean        0.000213        0.000192        0.000273       0.000459
# std         0.011475        0.002378        0.003067       0.010232
# skew       -0.235424       -0.157055       -2.110034      -0.321348

# %%
SPTR=data_pct.iloc[:,1]

# %%
scs.jarque_bera(SPTR)
# Out:
# (80238.26507648197, 0.0)

# %%
def w_jb_test(x):
    return scs.jarque_bera(x)[0]
def p_jb_test(x):
    return scs.jarque_bera(x)[1]

# %%
w=pd.DataFrame(data_pct.apply(w_jb_test),columns=['w']).T
p=pd.DataFrame(data_pct.apply(p_jb_test),columns=['p']).T

# %%
w
# Out:
#      SPTR Index  FNERTR Index  RU10INTR Index  SPGSCITR Index  GDDUEAFE Index  \
# w  12010.035635  80238.265076    11549.533551     1046.466879     7656.203718
#
#    LBUSTRUU Index  LF98TRUU Index  GDLEEGF Index
# w      433.312861   199016.632412    9578.279115

# %%
results=pd.concat([pct_mean,pct_std,pct_skew,w,p])

# %%
results
# Out:
#         SPTR Index  FNERTR Index  RU10INTR Index  SPGSCITR Index  \
# mean      0.000286      0.000572        0.000298        0.000148
# std       0.012398      0.018276        0.012473        0.014844
# skew      0.001377      0.415645       -0.020924       -0.140288
# w     12010.035635  80238.265076    11549.533551     1046.466879
# p         0.000000      0.000000        0.000000        0.000000
#
#       GDDUEAFE Index  LBUSTRUU Index  LF98TRUU Index  GDLEEGF Index
# mean        0.000213        0.000192        0.000273       0.000459
# std         0.011475        0.002378        0.003067       0.010232
# skew       -0.235424       -0.157055       -2.110034      -0.321348
# w        7656.203718      433.312861   199016.632412    9578.279115
# p           0.000000        0.000000        0.000000       0.000000

# %%
def f(x):
    return np.log(x/x.shift(1))

# %%
data_log = data.apply(f)

# %%
data_log
# Out:
#             SPTR Index  FNERTR Index  RU10INTR Index  SPGSCITR Index  \
# Date
# 1999-01-04         NaN           NaN             NaN             NaN
# 1999-01-05    0.013532      0.003753        0.012226       -0.008660
# 1999-01-06    0.022122      0.001502        0.021112        0.029356
# 1999-01-07   -0.001993     -0.006771       -0.000947        0.002094
# 1999-01-08    0.004213      0.000300        0.004273        0.003754
# ...                ...           ...             ...             ...
# 2016-12-02    0.000397      0.010451        0.000402        0.004212
# 2016-12-05    0.005901      0.007906        0.006356        0.009797
# 2016-12-06    0.003433      0.004533        0.004033       -0.007849
# 2016-12-07    0.013271      0.020441        0.012925       -0.011500
# 2016-12-08    0.002257      0.005542        0.002797        0.007605
#
#             GDDUEAFE Index  LBUSTRUU Index  LF98TRUU Index  GDLEEGF Index
# Date
# ...
